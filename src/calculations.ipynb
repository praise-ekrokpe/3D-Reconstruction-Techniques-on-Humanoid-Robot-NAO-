# %% [markdown]
# Camera Intrinsic Matrix

# %%
import numpy as np

Fx=[621.4050444342651, 621.9069407926571, 621.5741120877738, 621.3341658518179, 623.2002773813878, 619.8429503987622, 621.7555301964533, 621.2902695939529, 622.7367632580335, 619.8840591856967]
Cx=[321.1360058499139, 321.6927164136503, 321.7824176221655, 322.1805020393038, 321.5738868891722, 322.6370813350571, 320.3131222735401, 319.2237370138744, 321.3500261052071, 320.5945481468871]
Fy=[624.404203637617, 625.0646101238873, 624.4807467264302, 624.3930425258671, 626.3925102681991, 623.1306616825877, 624.9950761436472, 624.1866692215488, 625.8411126463177, 623.0935535272964]
Cy=[243.7385863180728, 244.5890682006883, 240.1330829151803, 245.0623334257779, 242.9604904540116, 244.7182345117245, 245.259997761041, 242.3618916641109, 244.5697515220066, 245.9247967744449]
repErr = [0.398292, 0.374087, 0.384061, 0.38687, 0.37416, 0.409669, 0.405849, 0.398807, 0.346496, 0.37008]
fx=np.mean(Fx)
fy=np.mean(Fy)
cx=np.mean(Cx)
cy=np.mean(Cy)
rE = np.mean(repErr)
print(fx)
print(cx)
print(fy)
print(cy)
print(rE)
print('===========')
print((fx+fy)/2)
# Out:
# 621.4930113180801
# 321.2484043688772
# 624.59821865034
# 243.93182335470593
# 0.38483710000000004
# ...
# 623.04561498421
